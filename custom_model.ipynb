# %%
import pandas as pd
import numpy as np
from imblearn.over_sampling import RandomOverSampler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from imblearn.over_sampling import RandomOverSampler
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
base_dir='./data/ham10000'

# %%
meta_df=pd.read_csv(base_dir+'/HAM10000_metadata')

# %%
distribution = meta_df['dx'].value_counts()
distribution
# Out:
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: dx, dtype: int64

# %%
distribution.plot()
# Out:
# <Axes: >

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from imblearn.over_sampling import RandomOverSampler
#
# ModuleNotFoundError: No module named 'imblearn'
